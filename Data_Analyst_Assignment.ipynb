# %% [markdown]
# <a href="https://colab.research.google.com/github/giocarro/Data_Science_Gio/blob/main/Data_Analyst_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Analyst Interview Notebook

# %% [markdown]
# ## Introduction
#
# This notebook is designed to simulate real-world data that you could see from our technology.
#
# It is designed to test your proficiency with Python and Pandas, and your ability to find and present insights.
#
# This data is confidential; we expect you to not share this data with anyone. And we expect you to not get any external assistance.
#
#
#
# ---
#
#
# You are working with a US retail customer on a pilot deployment.  They are using technology to track their merchandise throughout their supply chain.  The flow of their supply is:
#
# *   **DC 1:**  Orders are filled and palletized.
# *   **Truck:** Pallets travel from the DC 1 to DC 2 via semi-truck.
# *   **DC 2:**  Pallets are unloaded, and additional merchandise may be added.  They are then reloaded onto a new truck.
# *   **Truck:** Pallets travel from DC 2 to the Store.
# *   **Store:** Pallets are unloaded, cases are removed, and stocked, and the empty cases are left behind the building awaiting pickup.
#
# Your job is to dig into the data and find compelling insights to show the value fo the technology and help move the contract from a pilot into a full scaled deployment.
#
#
#
# ---
#
# Each section has defined questions along with point values to help you prioritize your time.
#
# In addition to the defined questions, the overall notebook and code presentation will be evaluated, and you will be awarded up to 10 points based on the clarity, cleaniness, and efficiency of the code.

# %% [markdown]
# ## Part 0: Imports
#
# Import necessary packages and

# %%
# YOUR CODE HERE:

import pandas as pd
import plotly.express as px

# %%
# Cargar Archivo desde Google Drive
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
df = pd.read_excel('tote_shipment.xlsx')
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# 1           73.4
# 2           73.4
# 3           74.3
# 4           73.4

# %% [markdown]
# ### Dataset Overview
#
# * Site:  A large space that could contain multiple readers. Ex: DC 1.
# * Zone:  Point of interest. These represent areas in which repeaters are installed. These can be thought of as sub-zones.  Ex: Dock Doors.
# * Asset ID: The unique ID of the asset.
# * Asset Type: The type of thing that is detected (ie tote).
# * Device ID: The unique gateway reader ID that detected the device in the zone (there can be multiple in one zone).
# * Time est: The time in EST.
# * Lon: Longituge
# * Lat: Latitude
# * Temperature_C / F: Temperature in Celsius, Fahrentheit

# %% [markdown]
# ## PART 1: Data Overview

# %% [markdown]
# ### Question 1:
#
# * How many unique cases were we tracking throughout this pilot. (1 pt)
# * What are the unique zones we could see (1 pt)
# * How many POI's are in each Zone. (2 pts)

# %%
# YOUR CODE HERE:
# How many unique cases were we tracking throughout this pilot. (1 pt)
df['Site'].unique()
# Out:
# array(['DC 1', 'DC 2', 'Transit', 'Store'], dtype=object)

# %%
df['Site'].nunique()
# Out:
# 4

# %%
# What are the unique zones we could see (1 pt)
df['Zone'].unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
df['Zone'].nunique()
# Out:
# 15

# %%
# How many POI's are in each Zone. (2 pts)
df['Zone'].unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
pd.DataFrame(df.groupby(['Site'])['Zone'].unique().reset_index().rename(columns = {'Zone':'POI'}))
# Out:
#       Site                                                POI
# 0     DC 1  [dock_doors_DC1, Forklift3_DC1, pallet_assembl...
# 1     DC 2                      [dock_doors_DC2, staging_DC2]
# 2    Store  [point_of_sale_Store, receiving_Store, store_b...
# 3  Transit  [PhoneKit1Bridge, PhoneKit2Bridge, PhoneKit2GW...

# %%
pd.DataFrame(df.groupby(['Site'])['Zone'].nunique().reset_index().rename(columns = {'Zone':'POI'}))
# Out:
#       Site  POI
# 0     DC 1    5
# 1     DC 2    2
# 2    Store    4
# 3  Transit    4

# %% [markdown]
# ### Question 2:
#
# * What is the temperature range we see?  (1pt)
# * Where is temperature the highest and lowest (1pt)

# %%
# YOUR CODE HERE:
# What is the temperature range we see? (1pt)
df['Temperature_C'].max() - df['Temperature_C'].min()
# Out:
# 25.0

# %%
# Highest temperature
df['Temperature_C'].max()
# Out:
# 44.0

# %%
# Lowest temperature
df['Temperature_C'].min()
# Out:
# 19.0

# %% [markdown]
# ## Part 2: The Journey of a Case

# %% [markdown]
# ### Question 3:
#
# * Create a visualization that shows where a case was at over time at the zone or POI level. Imagine that this would be included in your presentation to the customer. (Non techical audience) (3 pts)

# %%
# Libreria para manipular variables tipo tiempo
from datetime import datetime, date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   asset_type     130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Site           130061 non-null  object
#  4   Zone           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
#  11  Fecha          130061 non-null  object
#  12  Time           130061 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 12.9+ MB

# %%
df['asset_id'].unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df.groupby(['asset_id'])
df['asset_id'].unique()

# %%
df['time_est'].nunique()
# Out:
# 129887

# %%
df.groupby(['time_est']).asset_id.nunique()
# Out:
# time_est
# 2022-08-02 10:14:54.326    1
# 2022-08-02 10:15:38.860    1
# 2022-08-02 10:17:23.366    1
# 2022-08-02 10:18:23.847    1
# 2022-08-02 10:20:43.706    1
#                           ..
# 2022-08-05 13:28:26.584    1
# 2022-08-05 13:28:27.564    1
# 2022-08-05 13:28:28.172    1
# 2022-08-05 13:28:28.576    1
# 2022-08-05 13:28:29.966    1
# Name: asset_id, Length: 129887, dtype: int64

# %%
df['Fecha'] = pd.to_datetime(df['time_est']).dt.date
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha
# 0           73.4  2022-08-02
# 1           73.4  2022-08-02
# 2           73.4  2022-08-02
# 3           74.3  2022-08-02
# 4           73.4  2022-08-02

# %%
df['Time'] = pd.to_datetime(df['time_est']).dt.time
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha             Time
# 0           73.4  2022-08-02  11:59:26.628000
# 1           73.4  2022-08-02  12:00:22.660000
# 2           73.4  2022-08-02  12:01:11.234000
# 3           74.3  2022-08-02  13:47:58.172000
# 4           73.4  2022-08-02  11:58:55.049000

# %%
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha             Time
# 0           73.4  2022-08-02  11:59:26.628000
# 1           73.4  2022-08-02  12:00:22.660000
# 2           73.4  2022-08-02  12:01:11.234000
# 3           74.3  2022-08-02  13:47:58.172000
# 4           73.4  2022-08-02  11:58:55.049000

# %%
#Pending to check
df.groupby(['Fecha', 'Time','Site', 'Zone']).asset_id.unique()
# Out:
# Fecha       Time             Site   Zone
# 2022-08-02  10:14:54.326000  DC 1   Forklift1_DC1           [70]
#             10:15:38.860000  DC 1   pallet_assembly_DC1     [70]
#             10:17:23.366000  DC 1   staging_DC1             [37]
#             10:18:23.847000  DC 1   staging_DC1             [37]
#             10:20:43.706000  DC 1   dock_doors_DC1          [37]
#                                                            ...
# 2022-08-05  13:28:26.584000  Store  receiving_Store        [167]
#             13:28:27.564000  Store  receiving_Store        [200]
#             13:28:28.172000  Store  receiving_Store        [181]
#             13:28:28.576000  Store  receiving_Store         [59]
#             13:28:29.966000  Store  receiving_Store         [52]
# Name: asset_id, Length: 129914, dtype: object

# %%
# Caso 2
df_case_2 = df[df.asset_id == 2]
df_case_2
# Out:
#      asset_type  asset_id                           tag_id   Site  \
# 0          tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1          tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2          tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3          tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4          tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...         ...       ...                              ...    ...
# 6764       tote         2  (01)00850027865010(21)0082T0670  Store
# 6765       tote         2  (01)00850027865010(21)0082T0670  Store
# 6766       tote         2  (01)00850027865010(21)0082T0670  Store
# 6767       tote         2  (01)00850027865010(21)0082T0670  Store
# 6768       tote         2  (01)00850027865010(21)0082T0670  Store
#
#                    Zone     device_id                time_est        lat  \
# 0        dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.791580
# 1        dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.791580
# 2        dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.791580
# 3        dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.791580
# 4        dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.791580
# ...                 ...           ...                     ...        ...
# 6764  store_front_Store  6AF833197EE3 2022-08-05 09:00:28.894  47.749230
# 6765  store_front_Store  6AF833197EE3 2022-08-05 09:00:50.535  47.749230
# 6766  store_front_Store  6AF833197EE3 2022-08-05 09:01:28.268  47.749230
# 6767  store_front_Store  6AF833197EE3 2022-08-05 09:02:57.199  47.749388
# 6768  store_front_Store  6AF833197EE3 2022-08-05 09:04:58.575  47.749230
#
#             lng  Temperature_C  Temperature_F       Fecha             Time
# 0    -65.689020           23.0           73.4  2022-08-02  11:59:26.628000
# 1    -65.689020           23.0           73.4  2022-08-02  12:00:22.660000
# 2    -65.689020           23.0           73.4  2022-08-02  12:01:11.234000
# 3    -65.689020           23.5           74.3  2022-08-02  13:47:58.172000
# 4    -65.689020           23.0           73.4  2022-08-02  11:58:55.049000
# ...         ...            ...            ...         ...              ...
# 6764 -65.641010           22.0           71.6  2022-08-05  09:00:28.894000
# 6765 -65.641010           22.0           71.6  2022-08-05  09:00:50.535000
# 6766 -65.641010           22.0           71.6  2022-08-05  09:01:28.268000
# 6767 -65.640811           22.0           71.6  2022-08-05  09:02:57.199000
# 6768 -65.641010           22.0           71.6  2022-08-05  09:04:58.575000
#
# [6769 rows x 13 columns]

# %%
df_case_2.groupby(['Fecha','Time','Site', 'Zone']).asset_id.unique()
# Out:
# Fecha       Time             Site   Zone
# 2022-08-02  10:59:58.887000  DC 1   pallet_assembly_DC1    [2]
#             11:00:27.633000  DC 1   pallet_assembly_DC1    [2]
#             11:16:33.564000  DC 1   pallet_assembly_DC1    [2]
#             11:17:25.682000  DC 1   pallet_assembly_DC1    [2]
#             11:18:11.883000  DC 1   pallet_assembly_DC1    [2]
#                                                           ...
# 2022-08-05  13:26:39.605000  Store  receiving_Store        [2]
#             13:27:15.800000  Store  receiving_Store        [2]
#             13:27:37.625000  Store  receiving_Store        [2]
#             13:28:16.376000  Store  receiving_Store        [2]
#             13:28:24.536000  Store  receiving_Store        [2]
# Name: asset_id, Length: 6769, dtype: object

# %%
import plotly.express as px

# %%
px.line(df_case_2, x='Time', y='Zone', markers = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a22b7d10-6d60-4d9b-971e-e758c8832ffb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a22b7d10-6d60-4d9b-971e-e758c8832ffb")) {                    Plotly.newPlot(                        "a22b7d10-6d60-4d9b-971e-e758c8832ffb",                        [{"hovertemplate":"Time=%{x}<br>Zone=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","showlegend":false,"x":["11:59:26.628000","12:00:22.660000","12:01:11.234000","13:47:58.172000","11:58:55.049000","13:22:09.038000","13:26:07.080000","10:59:28.892000","12:48:11.580000","13:02:29.755000","13:07:22.071000","13:19:10.666000","13:44:18.548000","12:03:48.817000","12:04:13.827000","12:22:11.728000","13:19:20.278000","13:19:46.216000","13:26:43.535000","13:47:13.262000","13:52:29.036000","12:02:27.028000","10:59:58.887000","11:00:27.633000","11:16:33.564000","11:17:25.682000","11:18:11.883000","11:18:50.439000","11:19:09.683000","11:19:55.148000","11:20:09.735000","11:20:57.410000","11:21:10.466000","11:22:24.804000","11:22:46.015000","11:23:13.756000","11:23:42.735000","11:24:24.479000","11:24:50.140000","11:26:37.067000","11:27:53.058000","11:30:51.465000","11:31:26.634000","11:31:42.913000","11:32:55.118000","11:33:16.160000","11:33:53.093000","11:34:26.720000","11:35:41.276000","11:36:27.664000","11:37:00.386000","11:39:29.048000","11:39:54.344000","11:40:26.529000","11:40:49.348000","11:41:19.367000","11:41:58.580000","11:42:26.276000","11:42:59.843000","11:43:10.831000","11:43:52.841000","11:44:55.979000","11:45:18.629000","11:45:55.715000","11:46:16.758000","11:47:33.263000","11:49:28.754000","11:49:48.725000","11:50:01.316000","11:50:59.368000","11:51:59.784000","11:52:50.161000","11:53:27.318000","11:55:04.447000","11:55:45.905000","11:56:04.187000","11:56:55.366000","11:57:08.923000","11:31:52.289000","11:36:53.973000","11:37:32.301000","11:38:01.963000","11:49:14.983000","11:51:29.945000","11:51:55.969000","11:57:10.900000","13:52:30.665000","14:26:19.336000","14:46:48.524000","15:24:19.839000","15:34:33.766000","16:22:20.573000","16:49:27.403000","18:17:30.261000","20:27:38.630000","21:53:38.280000","22:17:16.727000","23:27:15.703000","23:30:43.113000","23:33:29.245000","07:01:51.756000","14:10:45.122000","14:15:12.710000","14:23:40.875000","18:49:40.570000","23:33:38.983000","00:04:31.167000","00:17:34.358000","00:25:06.898000","00:48:24.182000","03:24:41.673000","06:18:55.424000","06:26:37.983000","06:35:29.658000","07:15:01.721000","07:44:24.626000","07:46:46.962000","07:57:26.134000","07:57:49.661000","08:56:01.346000","10:05:22.824000","10:23:24.302000","10:45:46.355000","03:43:01.260000","08:22:06.196000","08:26:12.915000","08:33:27.883000","14:46:16.221000","14:48:39.603000","15:30:33.343000","15:47:53.482000","16:21:45.814000","16:48:25.394000","17:48:05.324000","17:51:00.668000","18:02:26.448000","18:18:49.636000","18:23:54.706000","18:24:44.321000","18:34:49.622000","18:35:37.879000","19:03:32.289000","19:07:12.536000","19:13:24.878000","19:14:26.323000","19:20:06.762000","19:21:07.162000","21:12:45.567000","21:21:36.215000","21:44:12.752000","21:51:03.191000","22:53:58.226000","23:11:12.200000","23:13:31.145000","23:14:48.404000","23:19:08.856000","23:32:45.981000","23:33:50.956000","23:34:25.709000","06:55:29.942000","19:12:15.512000","19:34:50.070000","19:54:57.868000","22:28:36.271000","23:31:22.863000","23:32:09.794000","23:34:43.914000","23:42:14.263000","23:47:01.715000","00:00:20.014000","00:01:46.729000","00:15:35.494000","01:23:36.370000","01:47:03.008000","01:48:03.360000","01:53:57.454000","01:55:52.277000","04:11:21.420000","04:17:29.690000","04:24:28.957000","04:32:38. ...

# %%
px.line(df_case_2, x='Time', y='Zone', color = 'Fecha', markers = False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1ba721a5-5ea2-424a-a468-899a063ff977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba721a5-5ea2-424a-a468-899a063ff977")) {                    Plotly.newPlot(                        "1ba721a5-5ea2-424a-a468-899a063ff977",                        [{"hovertemplate":"Fecha=2022-08-02<br>Time=%{x}<br>Zone=%{y}<extra></extra>","legendgroup":"2022-08-02","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2022-08-02","showlegend":true,"x":["11:59:26.628000","12:00:22.660000","12:01:11.234000","13:47:58.172000","11:58:55.049000","12:03:48.817000","12:04:13.827000","12:22:11.728000","13:19:20.278000","13:19:46.216000","13:26:43.535000","13:47:13.262000","13:52:29.036000","12:02:27.028000","10:59:58.887000","11:00:27.633000","11:16:33.564000","11:17:25.682000","11:18:11.883000","11:18:50.439000","11:19:09.683000","11:19:55.148000","11:20:09.735000","11:20:57.410000","11:21:10.466000","11:22:24.804000","11:22:46.015000","11:23:13.756000","11:23:42.735000","11:24:24.479000","11:24:50.140000","11:26:37.067000","11:27:53.058000","11:30:51.465000","11:31:26.634000","11:31:42.913000","11:32:55.118000","11:33:16.160000","11:33:53.093000","11:34:26.720000","11:35:41.276000","11:36:27.664000","11:37:00.386000","11:39:29.048000","11:39:54.344000","11:40:26.529000","11:40:49.348000","11:41:19.367000","11:41:58.580000","11:42:26.276000","11:42:59.843000","11:43:10.831000","11:43:52.841000","11:44:55.979000","11:45:18.629000","11:45:55.715000","11:46:16.758000","11:47:33.263000","11:49:28.754000","11:49:48.725000","11:50:01.316000","11:50:59.368000","11:51:59.784000","11:52:50.161000","11:53:27.318000","11:55:04.447000","11:55:45.905000","11:56:04.187000","11:56:55.366000","11:57:08.923000","11:31:52.289000","11:36:53.973000","11:37:32.301000","11:38:01.963000","11:49:14.983000","11:51:29.945000","11:51:55.969000","11:57:10.900000","13:52:30.665000","14:26:19.336000","14:46:48.524000","15:24:19.839000","15:34:33.766000","16:22:20.573000","16:49:27.403000","18:17:30.261000","20:27:38.630000","21:53:38.280000","22:17:16.727000","23:27:15.703000","23:30:43.113000","23:33:29.245000","14:10:45.122000","14:15:12.710000","14:23:40.875000","18:49:40.570000","23:33:38.983000","14:46:16.221000","14:48:39.603000","15:30:33.343000","15:47:53.482000","16:21:45.814000","16:48:25.394000","17:48:05.324000","17:51:00.668000","18:02:26.448000","18:18:49.636000","18:23:54.706000","18:24:44.321000","18:34:49.622000","18:35:37.879000","19:03:32.289000","19:07:12.536000","19:13:24.878000","19:14:26.323000","19:20:06.762000","19:21:07.162000","21:12:45.567000","21:21:36.215000","21:44:12.752000","21:51:03.191000","22:53:58.226000","23:11:12.200000","23:13:31.145000","23:14:48.404000","23:19:08.856000","23:32:45.981000","23:33:50.956000","23:34:25.709000","19:12:15.512000","19:34:50.070000","19:54:57.868000","22:28:36.271000","23:31:22.863000","23:32:09.794000","23:34:43.914000","23:42:14.263000","23:47:01.715000","14:29:24.919000","15:58:57.848000","16:20:58.533000","17:27:02.772000","18:17:29.643000","18:29:41.053000","19:55:53.110000","21:09:16.932000","21:20:18.630000","22:15:08.263000","22:24:42.792000","14:39:16.140000","15:54:09.859000","18:47:07.961000","21:03:03.119000","23:33:15.227000","11:46:53.446000","11:59:59.248000","12:01:51.526000","12:05:22.531000","12:06:26.598000","12:09:52.368000","12:19:30.063000","12:20:22.217000","12:20:47.695000","12:25:22.285000","12:25:34.149000","12:26:55.642000","12:28:42.229000","12:29:10.884000","12:29:30.548000","12:32:17.502000","12:33:25.249000","12:34:58.975000","12:35:56.385000","12:38:27.008000","12:40:37.462000","12:41:53.629000","12:44:04.984000","12:44:39.254000","12:46:56.73900 ...

# %% [markdown]
# ### Question 4:
#
# * Visualize how the temperatue changes over time along its journey.  Imagine that this would be included in your presentation to the customer. (Non techical audience) (4 pts)

# %%
# YOUR CODE HERE:

px.scatter(df_case_2, x='Zone', y='time_est', color = 'Temperature_C')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="048208ba-bb5d-4d70-93b8-5281a757cd0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("048208ba-bb5d-4d70-93b8-5281a757cd0a")) {                    Plotly.newPlot(                        "048208ba-bb5d-4d70-93b8-5281a757cd0a",                        [{"hovertemplate":"Zone=%{x}<br>time_est=%{y}<br>Temperature_C=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[23.0,23.0,23.0,23.5,23.0,25.0,25.0,24.5,25.0,25.0,25.0,25.0,25.0,23.0,23.0,23.5,23.5,23.5,23.5,23.5,24.5,23.0,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,23.0,23.0,22.5,23.0,23.0,22.5,22.5,22.5,22.5,22.5,23.0,23.0,22.75,22.5,22.5,23.0,23.0,23.0,23.0,22.5,23.0,23.0,23.0,23.0,23.0,23.0,23.0,23.0,23.0,23.0,22.5,22.5,23.0,23.0,23.0,23.0,23.0,23.0,23.0,23.0,24.5,24.5,24.5,24.5,25.5,26.0,26.0,26.0,26.5,26.0,26.0,26.0,26.0,26.0,24.0,24.0,24.0,24.5,26.5,26.0,25.5,25.5,26.0,25.5,25.0,24.5,24.5,24.5,24.5,24.5,24.5,24.0,24.0,24.5,24.0,24.5,24.5,25.0,24.0,24.5,24.5,24.5,24.5,25.5,25.5,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,24.0,26.5,26.5,27.0,26.0,26.0,26.0,26.0,26.0,26.0,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.0,25.0,25.0,25.0,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,25.0,25.0,25.0,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.0,24.5,25.5,26.0,26.5,26.0,26.5,26.5,26.0,26.0,26.0,26.0,24.0,24.5,25.5,26.5,26.5,26.0,25.5,24.5,24.5,24.5,24.0,24.5,25.0,24.0,24.0,24.5,21.0,21.0,22.5,22.5,24.0,24.0,22.0,22.0,22.5,22.5,22.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,25.0,24.5,24.5,24.5,25.0,25.0,24.83,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,24.92,25.0,25.0,24.83,24.96,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.25,25.5,25.5,25.5,25.5,25.5,25.5,26.0,26.0,26.0,25.7,25.63,26.0,26.5,26.5,27.0,27.0,27.0,27.0,27.0,27.5,27.5,26.75,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.5,27.83,28.0,28.0,28.0,28.0,28.0,28.0,23.5,23.5,23.5,23.0,23.0,23.0,23.33,23.06,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.14,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,21.5,23.0,22.0,22.0,22.0,22.0,22.0,22.0,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,22.5,23.0,23.0,23.0,23.0,23.0,23.0,23.0,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,23.5,24.0,24.0,24.0,24.0,24.0,24.0,24.0,24.0,24.0,24.0,24.33,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,24.5,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.5,25.72,26.0,25.5,25.5,25.61,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.25,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.0,26.5,26.5,26.5,26.0,26.17,26.5,26.0,26.0,26.0,26.1,26.5,26.25,26.38,26.0,26.0,26.0,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26.5,26. ...

# %% [markdown]
# ### Question 5:
# * Visualize the lon lat data on a map to show how the case traveled.  You may incorporate any other additional information to make this more impactful. Imagine that this would be included in your presentation to the customer. (Non techical audience) (5 pts)
#
# **Do not worry if this looks like non-sense on a map.  Ex:  The trip may appear to occur over water or in a forest because this is a toy dataset.**

# %%
# YOUR CODE HERE:
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha             Time
# 0           73.4  2022-08-02  11:59:26.628000
# 1           73.4  2022-08-02  12:00:22.660000
# 2           73.4  2022-08-02  12:01:11.234000
# 3           74.3  2022-08-02  13:47:58.172000
# 4           73.4  2022-08-02  11:58:55.049000

# %% [markdown]
# # Part 3: Customer Questions

# %% [markdown]
# ### Question 6:
#
# The customer wants to understand the efficieny of ther DC operations.
# * Based on what you see in the data, (all zones except for STORE), which parts of their operation are most & least "efficient? (10 pts)

# %%
# YOUR CODE HERE
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha             Time
# 0           73.4  2022-08-02  11:59:26.628000
# 1           73.4  2022-08-02  12:00:22.660000
# 2           73.4  2022-08-02  12:01:11.234000
# 3           74.3  2022-08-02  13:47:58.172000
# 4           73.4  2022-08-02  11:58:55.049000

# %%
df_case_2.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F       Fecha             Time
# 0           73.4  2022-08-02  11:59:26.628000
# 1           73.4  2022-08-02  12:00:22.660000
# 2           73.4  2022-08-02  12:01:11.234000
# 3           74.3  2022-08-02  13:47:58.172000
# 4           73.4  2022-08-02  11:58:55.049000

# %%
df_no_store = df_case_2(df_case_2.Site != 'Store')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-108-a8633279973a>", line 1, in <cell line: 1>
#     df_no_store = df_case_2(df_case_2.Site != 'Store')
# TypeError: 'DataFrame' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-108-a8633279973a>", line 1, in <cell line: 1>
#     df_no_store = df_case_2(df_case_2.Site != 'Store')
# TypeError: 'DataFrame' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-108-a8633279973a>", line 1, in <cell line: 1>
#     df_no_store = df_case_2(df_case_2.Site != 'Store')
# TypeError: 'DataFrame' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
df_case_2['Zone'].unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store'], dtype=object)

# %%
df_case_2.groupby(['Site','Zone','time_est']).asset_id.unique()
# Out:
# Site     Zone           time_est
# DC 1     Forklift3_DC1  2022-08-02 12:02:27.028    [2]
#                         2022-08-02 12:03:48.817    [2]
#                         2022-08-02 12:04:13.827    [2]
#                         2022-08-02 12:22:11.728    [2]
#                         2022-08-02 13:19:20.278    [2]
#                                                   ...
# Transit  PhoneKit2GW    2022-08-03 09:24:52.084    [2]
#                         2022-08-04 03:40:38.954    [2]
#                         2022-08-04 06:47:40.927    [2]
#                         2022-08-04 07:49:08.749    [2]
#                         2022-08-04 07:55:30.421    [2]
# Name: asset_id, Length: 6769, dtype: object

# %%
df_case_2.groupby(['time_est','Site','Zone']).asset_id.unique()
# Out:
# time_est                 Site   Zone
# 2022-08-02 10:59:58.887  DC 1   pallet_assembly_DC1    [2]
# 2022-08-02 11:00:27.633  DC 1   pallet_assembly_DC1    [2]
# 2022-08-02 11:16:33.564  DC 1   pallet_assembly_DC1    [2]
# 2022-08-02 11:17:25.682  DC 1   pallet_assembly_DC1    [2]
# 2022-08-02 11:18:11.883  DC 1   pallet_assembly_DC1    [2]
#                                                       ...
# 2022-08-05 13:26:39.605  Store  receiving_Store        [2]
# 2022-08-05 13:27:15.800  Store  receiving_Store        [2]
# 2022-08-05 13:27:37.625  Store  receiving_Store        [2]
# 2022-08-05 13:28:16.376  Store  receiving_Store        [2]
# 2022-08-05 13:28:24.536  Store  receiving_Store        [2]
# Name: asset_id, Length: 6769, dtype: object

# %%
df_case_2.groupby(['Site','Zone','time_est']).Temperature_C.max()
# Out:
# Site     Zone           time_est
# DC 1     Forklift3_DC1  2022-08-02 12:02:27.028    23.0
#                         2022-08-02 12:03:48.817    23.0
#                         2022-08-02 12:04:13.827    23.0
#                         2022-08-02 12:22:11.728    23.5
#                         2022-08-02 13:19:20.278    23.5
#                                                    ...
# Transit  PhoneKit2GW    2022-08-03 09:24:52.084    24.5
#                         2022-08-04 03:40:38.954    25.0
#                         2022-08-04 06:47:40.927    24.0
#                         2022-08-04 07:49:08.749    24.0
#                         2022-08-04 07:55:30.421    24.0
# Name: Temperature_C, Length: 6769, dtype: float64

# %%
dfr_1 = pd.DataFrame(df_case_2.groupby(['Site','Zone','time_est']).Temperature_C.max())

# %%
dfr_1.shape
# Out:
# (6769, 1)

# %%
dfr_1.head(40)
# Out:
#                                                   Temperature_C
# Site Zone                time_est
# DC 1 Forklift3_DC1       2022-08-02 12:02:27.028           23.0
#                          2022-08-02 12:03:48.817           23.0
#                          2022-08-02 12:04:13.827           23.0
#                          2022-08-02 12:22:11.728           23.5
#                          2022-08-02 13:19:20.278           23.5
#                          2022-08-02 13:19:46.216           23.5
#                          2022-08-02 13:26:43.535           23.5
#                          2022-08-02 13:47:13.262           23.5
#                          2022-08-02 13:52:29.036           24.5
#      dock_doors_DC1      2022-08-02 11:58:55.049           23.0
#                          2022-08-02 11:59:26.628           23.0
#                          2022-08-02 12:00:22.660           23.0
#                          2022-08-02 12:01:11.234           23.0
#                          2022-08-02 13:47:58.172           23.5
#      pallet_assembly_DC1 2022-08-02 10:59:58.887           22.5
#                          2022-08-02 11:00:27.633           22.5
#                          2022-08-02 11:16:33.564           22.5
#                          2022-08-02 11:17:25.682           22.5
#                          2022-08-02 11:18:11.883           22.5
#                          2022-08-02 11:18:50.439           22.5
#                          2022-08-02 11:19:09.683           22.5
#                          2022-08-02 11:19:55.148           22.5
#                          2022-08-02 11:20:09.735           22.5
#                          2022-08-02 11:20:57.410           22.5
#                          2022-08-02 11:21:10.466           22.5
#                          2022-08-02 11:22:24.804           22.5
#                          2022-08-02 11:22:46.015           22.5
#                          2022-08-02 11:23:13.756           22.5
#                          2022-08-02 11:23:42.735           22.5
#                          2022-08-02 11:24:24.479           22.5
#                          2022-08-02 11:24:50.140           22.5
#                          2022-08-02 11:26:37.067           22.5
#                          2022-08-02 11:27:53.058           22.5
#                          2022-08-02 11:30:51.465           22.5
#                          2022-08-02 11:31:26.634           22.5
#                          2022-08-02 11:31:42.913           22.5
#                          2022-08-02 11:31:52.289           23.0
#                          2022-08-02 11:32:55.118           22.5
#                          2022-08-02 11:33:16.160           22.5
#                          2022-08-02 11:33:53.093           23.0

# %% [markdown]
# YOUR TEXT ANSWER HERE

# %% [markdown]
# ### Question 7:
#
# The customer wants to understand the stocking efficiency in stores.
# * Based on what you see in the data, how quickly did the store unload and stock the merchandise. (5 pts)
# * How could this be converted in a KPI that a regional manager could track?  (5 pts)

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR TEXT ANSWER HERE

# %% [markdown]
# ### Question 8:
#
# Please explain what you would ask for and what you will do with this data, given that you can talk with the following people (no code needed):

# %% [markdown]
# YOUR TEXT ANSWER HERE
# * a. X
# * b. Y

# %% [markdown]
# ## Part 4: Bonus Insights

# %% [markdown]
# ### Question 8
#
# The customer is open to hearing about additional insights you found in the data above and beyond what they asked for.
# * Based on what you can see in the data, are there any other interesting insights that the customer may want to hear about? (Up to 15 bonus points)

# %%
# YOUR CODE HERE
# Another metrics that could be interesting would be temperature by time

# %% [markdown]
# YOUR TEXT ANSWER HERE
